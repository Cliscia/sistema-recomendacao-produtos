# %% [markdown]
# # Sistema de Recomendação de Produtos (TF-IDF + Similaridade do Cosseno)
#
# Projeto de portfólio — recomendação por **produto** e por **intenção do usuário** usando **NLP clássico**.
#
# **Objetivo:** simular um recomendador de e-commerce (content-based), transformando descrições de produtos em vetores e calculando similaridade para sugerir itens relevantes.

# %% [markdown]
# ## Sumário
# 1. Carregamento dos dados
# 2. Criação do texto descritivo (feature engineering)
# 3. Vetorização TF-IDF
# 4. Similaridade do cosseno
# 5. Recomendação por nome do produto
# 6. Recomendação por descrição (intenção do usuário)
# 7. Exibição dos resultados (visual clean)
# 8. Exemplos de uso

# %% [markdown]
# ## 1. Carregamento dos dados

# %%
import pandas as pd

# %%
df = pd.read_csv("produtos.csv")
df.head()
# Out:
#    product_id                              name category  price_brl  \
# 0           1  Jogo de Panelas Antiaderente 5pç  Cozinha      349.9
# 1           2        Conjunto de Facas Inox 6pç  Cozinha      129.9
# 2           3           Assadeira Retangular 3L  Cozinha       69.9
# 3           4             Tábua de Corte Bamboo  Cozinha       59.9
# 4           5               Airfryer 4L Digital  Cozinha      429.0
#
#                        material          brand  \
# 0                      Alumínio  Praticli Home
# 1                Aço Inoxidável       ChefLine
# 2               Vidro Temperado      GlassCook
# 3                         Bambu       EcoBoard
# 4  PP + Componentes Eletrônicos        AirLite
#
#                                                 tags  rating
# 0   panelas antiaderente fogão cozinha fácil limpeza     4.6
# 1  facas inox cozinha corte preciso suporte magné...     4.4
# 2            assadeira forno lasanha gratinado vidro     4.5
# 3             tábua corte bamboo sustentável cozinha     4.7
# 4      airfryer fritadeira sem óleo digital saudável     4.8

# %%
import pandas as pd, re

def to_float_brl(x):
    if pd.isna(x):
        return None
    s = str(x).strip()
    s = re.sub(r"[^\d,.\-]", "", s)
    if "," in s and "." in s:
        s = s.replace(".", "").replace(",", ".")
    elif "," in s and "." not in s:
        s = s.replace(",", ".")
    try:
        return float(s)
    except:
        return None

df["price_brl"] = df["price_brl"].apply(to_float_brl)

# %% [markdown]
# ## 2. Criação do texto descritivo (feature engineering)
# Unifica nome, categoria, material, marca, tags, preço e nota em uma única coluna textual para representar semanticamente cada produto.

# %%
def make_text(row):
    parts = [
        str(row["name"]),
        str(row["category"]),
        str(row["material"]),
        str(row["brand"]),
        str(row["tags"]),
        f"preco {row['price_brl']:.2f}",
        f"nota {row['rating']:.1f}"
    ]
    return " ".join(parts)
df["text"] = df.apply(make_text, axis=1)
df[["product_id","name","text"]].head(5)
# Out:
#    product_id                              name  \
# 0           1  Jogo de Panelas Antiaderente 5pç
# 1           2        Conjunto de Facas Inox 6pç
# 2           3           Assadeira Retangular 3L
# 3           4             Tábua de Corte Bamboo
# 4           5               Airfryer 4L Digital
#
#                                                 text
# 0  Jogo de Panelas Antiaderente 5pç Cozinha Alumí...
# 1  Conjunto de Facas Inox 6pç Cozinha Aço Inoxidá...
# 2  Assadeira Retangular 3L Cozinha Vidro Temperad...
# 3  Tábua de Corte Bamboo Cozinha Bambu EcoBoard t...
# 4  Airfryer 4L Digital Cozinha PP + Componentes E...

# %% [markdown]
# ## 3. Vetorização TF-IDF
# Transforma o texto em vetores numéricos para permitir comparação.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Criamos o transformador TF-IDF
tfidf = TfidfVectorizer()

# Aplicamos ele ao texto dos produtos
X = tfidf.fit_transform(df["text"])

X.shape
# Out:
# (10, 98)

# %% [markdown]
# ## 4. Similaridade do cosseno
# Mede quão semelhantes são os vetores dos produtos entre si.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calcula a similaridade entre todos os produtos
sim_matrix = cosine_similarity(X)

sim_matrix.shape
# Out:
# (10, 10)

# %% [markdown]
# ## 5. Recomendação por nome do produto
# Busca itens similares a um produto específico (item-based).

# %%
import numpy as np

def recomendar(nome_produto, top_n=5):
    # encontra o índice do produto cujo nome foi buscado
    mask = df["name"].str.contains(nome_produto, case=False)
    if not mask.any():
        return "Produto não encontrado. Tente parte do nome (ex: 'Airfryer', 'Tábua')."

    idx = df[mask].index[0]

    # pega as similaridades deste produto para todos os outros
    scores = sim_matrix[idx]

    # ordena do mais parecido para o menos
    indices_similares = np.argsort(scores)[::-1]

    # remove o próprio produto da lista
    indices_similares = [i for i in indices_similares if i != idx]

    # pega os top N mais parecidos
    similares = indices_similares[:top_n]

    return df.loc[similares, ["product_id", "name", "category", "price_brl", "rating"]]

# %% [raw]
# recomendar("Airfryer")

# %%
recomendar("Airfryer")
# Out:
#    product_id                              name     category  price_brl  \
# 3           4             Tábua de Corte Bamboo      Cozinha       59.9
# 1           2        Conjunto de Facas Inox 6pç      Cozinha      129.9
# 0           1  Jogo de Panelas Antiaderente 5pç      Cozinha      349.9
# 2           3           Assadeira Retangular 3L      Cozinha       69.9
# 9          10              Potes Herméticos 5pç  Organização       99.9
#
#    rating
# 3     4.7
# 1     4.4
# 0     4.6
# 2     4.5
# 9     4.5

# %% [markdown]
# ## 6. Recomendação por descrição (intenção do usuário)
# Converte a frase do cliente para o mesmo espaço vetorial e encontra os itens mais relevantes.

# %%
def recomendar_por_descricao(texto_cliente, top_n=5):
    # Transformamos o texto do cliente no mesmo formato dos produtos
    texto_vec = tfidf.transform([texto_cliente])

    # Calculamos a similaridade do texto com todos os produtos
    scores = cosine_similarity(texto_vec, X)[0]

    # Ordenamos os produtos do mais parecido para o menos
    indices_similares = np.argsort(scores)[::-1]

    # Pegamos os top N produtos mais relevantes
    similares = indices_similares[:top_n]

    return df.loc[similares, ["product_id", "name", "category", "price_brl", "rating"]]

# %%
recomendar_por_descricao("quero itens sustentáveis")
# Out:
#    product_id                                name     category  price_brl  \
# 9          10                Potes Herméticos 5pç  Organização       99.9
# 8           9  Kit Organizadores de Geladeira 6pç  Organização      119.9
# 7           8            Jogo Americano 4pç Linho         Mesa       79.9
# 6           7             Garrafa Térmica 1L Inox         Mesa      139.9
# 5           6              Jogo de Copos 6x 300ml         Mesa       49.9
#
#    rating
# 9     4.5
# 8     4.4
# 7     4.2
# 6     4.6
# 5     4.3

# %%
recomendar_por_descricao("quero organizar minha despensa")
# Out:
#    product_id                                name     category  price_brl  \
# 9          10                Potes Herméticos 5pç  Organização       99.9
# 8           9  Kit Organizadores de Geladeira 6pç  Organização      119.9
# 7           8            Jogo Americano 4pç Linho         Mesa       79.9
# 6           7             Garrafa Térmica 1L Inox         Mesa      139.9
# 5           6              Jogo de Copos 6x 300ml         Mesa       49.9
#
#    rating
# 9     4.5
# 8     4.4
# 7     4.2
# 6     4.6
# 5     4.3

# %%
recomendar_por_descricao("quero algo prático para cozinha")
# Out:
#    product_id                              name     category  price_brl  \
# 3           4             Tábua de Corte Bamboo      Cozinha       59.9
# 1           2        Conjunto de Facas Inox 6pç      Cozinha      129.9
# 0           1  Jogo de Panelas Antiaderente 5pç      Cozinha      349.9
# 2           3           Assadeira Retangular 3L      Cozinha       69.9
# 9          10              Potes Herméticos 5pç  Organização       99.9
#
#    rating
# 3     4.7
# 1     4.4
# 0     4.6
# 2     4.5
# 9     4.5

# %%
# tenta converter a coluna para float; se algo não converter, vira NaN
df["price_brl"] = pd.to_numeric(df["price_brl"], errors="coerce")

# %% [markdown]
# ## 7. Exibição dos resultados (visual clean)
# Formatação apenas para visualização (não altera os dados).

# %%
def mostrar_recomendacao_clean(df_result, titulo="Recomendações"):
    df_show = df_result.copy()

    def brl(v):
        if pd.isna(v): return ""
        return f"R${v:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

    if "price_brl" in df_show.columns:
        df_show["price_brl"] = df_show["price_brl"].apply(brl)
    if "rating" in df_show.columns:
        df_show["rating"] = df_show["rating"].map(lambda x: f"{x:.1f}")

    df_show = df_show.rename(columns={
        "product_id": "ID",
        "name": "Produto",
        "category": "Categoria",
        "price_brl": "Preço",
        "rating": "Avaliação"
    })

    styled = (
        df_show.style
        .set_caption(titulo)
        .hide(axis="index")
        .set_table_styles([
            {"selector": "caption", "props": "caption-side: top; text-align: left; font-weight: 600; font-size: 15px; padding: 4px 0;"},
            {"selector": "th", "props": "background-color: #f4f4f4; color: #111; font-weight: 600; border-bottom: 1px solid #ddd;"},
            {"selector": "td", "props": "padding: 6px 8px; border-bottom: 1px solid #eee;"},
            {"selector": "table", "props": "border-collapse: collapse; margin: 8px 0;"},
        ])
        .set_properties(**{"font-size": "14px", "color": "#111"})
        .set_properties(subset=["ID","Preço","Avaliação"], **{"text-align": "right"})
        .set_properties(subset=["Produto","Categoria"], **{"text-align": "left"})
    )
    display(styled)

# %%
def brl(v):
    if pd.isna(v):
        return ""
    return f"R${v:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

# %% [markdown]
# ## 8. Exemplos de uso

# %%
res1 = recomendar("Airfryer")
mostrar_recomendacao_clean(res1, "Recomendações — similares a: Airfryer")
# Out:
# <style type="text/css">
# #T_4a009 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 600;
#   font-size: 15px;
#   padding: 4px 0;
# }
# #T_4a009 th {
#   background-color: #f4f4f4;
#   color: #111;
#   font-weight: 600;
#   border-bottom: 1px solid #ddd;
# }
# #T_4a009 td {
#   padding: 6px 8px;
#   border-bottom: 1px solid #eee;
# }
# #T_4a009 table {
#   border-collapse: collapse;
#   margin: 8px 0;
# }
# #T_4a009_row0_col0, #T_4a009_row0_col3, #T_4a009_row0_col4, #T_4a009_row1_col0, #T_4a009_row1_col3, #T_4a009_row1_col4, #T_4a009_row2_col0, #T_4a009_row2_col3, #T_4a009_row2_col4, #T_4a009_row3_col0, #T_4a009_row3_col3, #T_4a009_row3_col4, #T_4a009_row4_col0, #T_4a009_row4_col3, #T_4a009_row4_col4 {
#   font-size: 14px;
#   color: #111;
#   text-align: right;
# }
# #T_4a009_row0_col1, #T_4a009_row0_col2, #T_4a009_row1_col1, #T_4a009_row1_col2, #T_4a009_row2_col1, #T_4a009_row2_col2, #T_4a009_row3_col1, #T_4a009_row3_col2, #T_4a009_row4_col1, #T_4a009_row4_col2 {
#   font-size: 14px;
#   color: #111;
#   text-align: left;
# }
# </style>
# <table id="T_4a009">
#   <caption>Recomendações — similares a: Airfryer</caption>
#   <thead>
#     <tr>
#       <th id="T_4a009_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_4a009_level0_col1" class="col_heading level0 col1" >Produto</th>
#       <th id="T_4a009_level0_col2" class="col_heading level0 col2" >Categoria</th>
#       <th id="T_4a009_level0_col3" class="col_heading level0 col3" >Preço</th>
#       <th id="T_4a009_level0_col4" class="col_heading level0 col4" >Avaliação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4a009_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_4a009_row0_col1" class="data row0 col1" >Tábua de Corte Bamboo</td>
#       <td id="T_4a009_row0_col2" class="data row0 col2" >Cozinha</td>
#       <td id="T_4a009_row0_col3" class="data row0 col3" >R$59,90</td>
#       <td id="T_4a009_row0_col4" class="data row0 col4" >4.7</td>
#     </tr>
#     <tr>
#       <td id="T_4a009_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4a009_row1_col1" class="data row1 col1" >Conjunto de Facas Inox 6pç</td>
#       <td id="T_4a009_row1_col2" class="data row1 col2" >Cozinha</td>
#       <td id="T_4a009_row1_col3" class="data row1 col3" >R$129,90</td>
#       <td id="T_4a009_row1_col4" class="data row1 col4" >4.4</td>
#     </tr>
#     <tr>
#       <td id="T_4a009_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_4a009_row2_col1" class="data row2 col1" >Jogo de Panelas Antiaderente 5pç</td>
#       <td id="T_4a009_row2_col2" class="data row2 col2" >Cozinha</td>
#       <td id="T_4a009_row2_col3" class="data row2 col3" >R$349,90</td>
#       <td id="T_4a009_row2_col4" class="data row2 col4" >4.6</td>
#     </tr>
#     <tr>
#       <td id="T_4a009_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_4a009_row3_col1" class="data row3 col1" >Assadeira Retangular 3L</td>
#       <td id="T_4a009_row3_col2" class="data row3 col2" >Cozinha</td>
#       <td id="T_4a009_row3_col3" class="data row3 col3" >R$69,90</td>
#       <td id="T_4a009_row3_col4" class="data row3 col4" >4.5</td>
#     </tr>
#     <tr>
#       <td id="T_4a009_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_4a009_row4_col1" class="data row4 col1" >Potes Herméticos 5pç</td>
#       <td id="T_4a009_row4_col2" class="data row4 col2" >Organização</td>
#       <td id="T_4a009_row4_col3" class="data row4 col3" >R$99,90</td>
#       <td id="T_4a009_row4_col4" class="data row4 col4" >4.5</td>
#     </tr>
#   </tbody>
# </table>

# %%
res2 = recomendar_por_descricao("quero presente útil para alguém que gosta de cozinhar")
mostrar_recomendacao_clean(res2, "Recomendações — intenção: presente útil para quem cozinha")
# Out:
# <style type="text/css">
# #T_f6674 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 600;
#   font-size: 15px;
#   padding: 4px 0;
# }
# #T_f6674 th {
#   background-color: #f4f4f4;
#   color: #111;
#   font-weight: 600;
#   border-bottom: 1px solid #ddd;
# }
# #T_f6674 td {
#   padding: 6px 8px;
#   border-bottom: 1px solid #eee;
# }
# #T_f6674 table {
#   border-collapse: collapse;
#   margin: 8px 0;
# }
# #T_f6674_row0_col0, #T_f6674_row0_col3, #T_f6674_row0_col4, #T_f6674_row1_col0, #T_f6674_row1_col3, #T_f6674_row1_col4, #T_f6674_row2_col0, #T_f6674_row2_col3, #T_f6674_row2_col4, #T_f6674_row3_col0, #T_f6674_row3_col3, #T_f6674_row3_col4, #T_f6674_row4_col0, #T_f6674_row4_col3, #T_f6674_row4_col4 {
#   font-size: 14px;
#   color: #111;
#   text-align: right;
# }
# #T_f6674_row0_col1, #T_f6674_row0_col2, #T_f6674_row1_col1, #T_f6674_row1_col2, #T_f6674_row2_col1, #T_f6674_row2_col2, #T_f6674_row3_col1, #T_f6674_row3_col2, #T_f6674_row4_col1, #T_f6674_row4_col2 {
#   font-size: 14px;
#   color: #111;
#   text-align: left;
# }
# </style>
# <table id="T_f6674">
#   <caption>Recomendações — intenção: presente útil para quem cozinha</caption>
#   <thead>
#     <tr>
#       <th id="T_f6674_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_f6674_level0_col1" class="col_heading level0 col1" >Produto</th>
#       <th id="T_f6674_level0_col2" class="col_heading level0 col2" >Categoria</th>
#       <th id="T_f6674_level0_col3" class="col_heading level0 col3" >Preço</th>
#       <th id="T_f6674_level0_col4" class="col_heading level0 col4" >Avaliação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f6674_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_f6674_row0_col1" class="data row0 col1" >Tábua de Corte Bamboo</td>
#       <td id="T_f6674_row0_col2" class="data row0 col2" >Cozinha</td>
#       <td id="T_f6674_row0_col3" class="data row0 col3" >R$59,90</td>
#       <td id="T_f6674_row0_col4" class="data row0 col4" >4.7</td>
#     </tr>
#     <tr>
#       <td id="T_f6674_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_f6674_row1_col1" class="data row1 col1" >Jogo de Copos 6x 300ml</td>
#       <td id="T_f6674_row1_col2" class="data row1 col2" >Mesa</td>
#       <td id="T_f6674_row1_col3" class="data row1 col3" >R$49,90</td>
#       <td id="T_f6674_row1_col4" class="data row1 col4" >4.3</td>
#     </tr>
#     <tr>
#       <td id="T_f6674_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f6674_row2_col1" class="data row2 col1" >Conjunto de Facas Inox 6pç</td>
#       <td id="T_f6674_row2_col2" class="data row2 col2" >Cozinha</td>
#       <td id="T_f6674_row2_col3" class="data row2 col3" >R$129,90</td>
#       <td id="T_f6674_row2_col4" class="data row2 col4" >4.4</td>
#     </tr>
#     <tr>
#       <td id="T_f6674_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_f6674_row3_col1" class="data row3 col1" >Jogo de Panelas Antiaderente 5pç</td>
#       <td id="T_f6674_row3_col2" class="data row3 col2" >Cozinha</td>
#       <td id="T_f6674_row3_col3" class="data row3 col3" >R$349,90</td>
#       <td id="T_f6674_row3_col4" class="data row3 col4" >4.6</td>
#     </tr>
#     <tr>
#       <td id="T_f6674_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_f6674_row4_col1" class="data row4 col1" >Kit Organizadores de Geladeira 6pç</td>
#       <td id="T_f6674_row4_col2" class="data row4 col2" >Organização</td>
#       <td id="T_f6674_row4_col3" class="data row4 col3" >R$119,90</td>
#       <td id="T_f6674_row4_col4" class="data row4 col4" >4.4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9. Conclusão
#
# Neste projeto construí um sistema de recomendação de produtos baseado em conteúdo, utilizando TF-IDF para representar textos e similaridade do cosseno para encontrar itens mais próximos.
# Foram criados dois modos de recomendação: por nome do produto e por intenção do usuário em linguagem natural, simulando um cenário de e-commerce real.
#
# O modelo apresentou resultados coerentes e consistentes, capturando contexto sem necessidade de deep learning.
# Como próximos passos, é possível substituir TF-IDF por embeddings (ex.: Word2Vec ou BERT) para melhorar a compreensão semântica e expandir o sistema para uso em uma API ou interface web.
